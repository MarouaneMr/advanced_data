# %%
import pandas as pd
import numpy as np

# %%
industries = pd.read_csv("mappings/industries.csv")
industries
# Out:
#      industry_id                             industry_name
# 0              1           Defense and Space Manufacturing
# 1              3           Computer Hardware Manufacturing
# 2              4                      Software Development
# 3              5              Computer Networking Products
# 4              6      Technology, Information and Internet
# ..           ...                                       ...
# 417         3249            Surveying and Mapping Services
# 418         3250                         Retail Pharmacies
# 419         3251  Climate Technology Product Manufacturing
# 420         3252                Climate Data and Analytics
# 421         3253    Alternative Fuel Vehicle Manufacturing
#
# [422 rows x 2 columns]

# %%
unique_industries = industries['industry_name'].unique()
print(unique_industries)
# Out:
# ['Defense and Space Manufacturing' 'Computer Hardware Manufacturing'
#  'Software Development' 'Computer Networking Products'
#  'Technology, Information and Internet' 'Semiconductor Manufacturing'
#  'Telecommunications' 'Law Practice' 'Legal Services'
#  'Business Consulting and Services' 'Biotechnology Research'
#  'Medical Practices' 'Hospitals and Health Care'
#  'Pharmaceutical Manufacturing' 'Veterinary Services'
#  'Medical Equipment Manufacturing' 'Personal Care Product Manufacturing'
#  'Retail Apparel and Fashion' 'Sporting Goods Manufacturing'
#  'Tobacco Manufacturing' 'Retail Groceries'
#  'Food and Beverage Manufacturing'
#  'Computers and Electronics Manufacturing' 'Manufacturing'
#  'Furniture and Home Furnishings Manufacturing' 'Retail'
#  'Entertainment Providers' 'Gambling Facilities and Casinos'
#  'Travel Arrangements' 'Hospitality' 'Restaurants' 'Spectator Sports'
#  'Food and Beverage Services' 'Movies, Videos, and Sound'
# ...

# %%
cluster_mapping = {
    # Software and IT Services
    'Software Development': 'Software and IT Services',
    'IT Services and IT Consulting': 'Software and IT Services',
    'Computer Networking Products': 'Software and IT Services',
    'Data Security Software Products': 'Software and IT Services',
    'Internet News': 'Software and IT Services',
    'Internet Publishing': 'Software and IT Services',
    'Blockchain Services': 'Software and IT Services',
    # Hardware and Electronics
    'Computer Hardware Manufacturing': 'Hardware and Electronics',
    'Semiconductor Manufacturing': 'Hardware and Electronics',
    'Audio and Video Equipment Manufacturing': 'Hardware and Electronics',
    'Renewable Energy Semiconductor Manufacturing': 'Hardware and Electronics',
    # Telecommunications and Networking
    'Telecommunications': 'Telecommunications and Networking',
    'Wireless Services': 'Telecommunications and Networking',
    'Communications Equipment Manufacturing': 'Telecommunications and Networking',
    # Healthcare and Biotechnology
    'Biotechnology Research': 'Healthcare and Biotechnology',
    'Pharmaceutical Manufacturing': 'Healthcare and Biotechnology',
    'Hospitals and Health Care': 'Healthcare and Biotechnology',
    'Medical Equipment Manufacturing': 'Healthcare and Biotechnology',
    'Veterinary Services': 'Healthcare and Biotechnology',
    'Mental Health Care': 'Healthcare and Biotechnology',
    'Nursing Homes and Residential Care Facilities': 'Healthcare and Biotechnology',
    # Personal Care and Wellness
    'Personal Care Product Manufacturing': 'Personal Care and Wellness',
    'Wellness and Fitness Services': 'Personal Care and Wellness',
    'Alternative Medicine': 'Personal Care and Wellness',
    # Finance and Banking
    'Banking': 'Finance and Banking',
    'Investment Management': 'Finance and Banking',
    'Financial Services': 'Finance and Banking',
    'Insurance': 'Finance and Banking',
    'Venture Capital and Private Equity Principals': 'Finance and Banking',
    'Capital Markets': 'Finance and Banking',
    # Real Estate and Construction
    'Real Estate': 'Real Estate and Construction',
    'Architecture and Planning': 'Real Estate and Construction',
    'Building Construction': 'Real Estate and Construction',
    'Utility System Construction': 'Real Estate and Construction',
    'Leasing Non-residential Real Estate': 'Real Estate and Construction',
    # Food and Beverage
    'Food and Beverage Manufacturing': 'Food and Beverage',
    'Retail Groceries': 'Food and Beverage',
    'Baked Goods Manufacturing': 'Food and Beverage',
    'Beverage Manufacturing': 'Food and Beverage',
    'Wineries': 'Food and Beverage',
    'Food Production': 'Food and Beverage',
    # Retail and Consumer Goods
    'Retail Apparel and Fashion': 'Retail and Consumer Goods',
    'Sporting Goods Manufacturing': 'Retail and Consumer Goods',
    'Luxury Goods and Jewelry': 'Retail and Consumer Goods',
    'Retail Motor Vehicles': 'Retail and Consumer Goods',
    'Retail Building Materials and Garden Equipment': 'Retail and Consumer Goods',
    # Hospitality and Travel
    'Hospitality': 'Hospitality and Travel',
    'Restaurants': 'Hospitality and Travel',
    'Travel Arrangements': 'Hospitality and Travel',
    'Airlines and Aviation': 'Hospitality and Travel',
    'Bed-and-Breakfasts, Hostels, Homestays': 'Hospitality and Travel',
    'Caterers': 'Hospitality and Travel',
    # Energy and Utilities
    'Oil and Gas': 'Energy and Utilities',
    'Renewable Energy Equipment Manufacturing': 'Energy and Utilities',
    'Electric Power Generation': 'Energy and Utilities',
    'Wind Electric Power Generation': 'Energy and Utilities',
    'Solar Electric Power Generation': 'Energy and Utilities',
    # Transportation and Logistics
    'Truck Transportation': 'Transportation and Logistics',
    'Maritime Transportation': 'Transportation and Logistics',
    'Warehousing and Storage': 'Transportation and Logistics',
    'Transportation, Logistics, Supply Chain and Storage': 'Transportation and Logistics',
    'Rail Transportation': 'Transportation and Logistics',
    # Media and Entertainment
    'Broadcast Media Production': 'Media and Entertainment',
    'Performing Arts': 'Media and Entertainment',
    'Movies, Videos, and Sound': 'Media and Entertainment',
    'Online Media': 'Media and Entertainment',
    'Animation and Post-production': 'Media and Entertainment',
    # Education and Training
    'Primary and Secondary Education': 'Education and Training',
    'Higher Education': 'Education and Training',
    'E-Learning Providers': 'Education and Training',
    'Technical and Vocational Training': 'Education and Training',
    # Aerospace and Defense
    'Defense and Space Manufacturing': 'Aerospace and Defense',
    'Aviation and Aerospace Component Manufacturing': 'Aerospace and Defense',
    'Space Research and Technology': 'Aerospace and Defense',
    # Manufacturing and Industry
    'Textile Manufacturing': 'Manufacturing and Industry',
    'Chemical Manufacturing': 'Manufacturing and Industry',
    'Metalworking Machinery Manufacturing': 'Manufacturing and Industry',
    'Industrial Machinery Manufacturing': 'Manufacturing and Industry',
    # Environmental and Sustainability
    'Environmental Services': 'Environmental and Sustainability',
    'Climate Data and Analytics': 'Environmental and Sustainability',
    'Water, Waste, Steam, and Air Conditioning Services': 'Environmental and Sustainability',
    # Legal and Law Enforcement
    'Law Practice': 'Legal and Law Enforcement',
    'Administration of Justice': 'Legal and Law Enforcement',
    'Public Safety': 'Legal and Law Enforcement',
    'Legal Services': 'Legal and Law Enforcement',
    # Non-Profit and Civic Organizations
    'Non-profit Organizations': 'Non-Profit and Civic Organizations',
    'Religious Institutions': 'Non-Profit and Civic Organizations',
    'Civic and Social Organizations': 'Non-Profit and Civic Organizations',
    # Agriculture and Farming
    'Farming': 'Agriculture and Farming',
    'Dairy Product Manufacturing': 'Agriculture and Farming',
    'Animal Feed Manufacturing': 'Agriculture and Farming',
    'Forestry and Logging': 'Agriculture and Farming',
    # Sports and Recreation
    'Spectator Sports': 'Sports and Recreation',
    'Recreational Facilities': 'Sports and Recreation',
    'Golf Courses and Country Clubs': 'Sports and Recreation',
    'Amusement Parks and Arcades': 'Sports and Recreation',
    # Professional Services and Consulting
    'Strategic Management Services': 'Professional Services and Consulting',
    'Operations Consulting': 'Professional Services and Consulting',
    'Staffing and Recruiting': 'Professional Services and Consulting',
    # Marketing, Advertising, and Publishing
    'Advertising Services': 'Marketing, Advertising, and Publishing',
    'Newspaper Publishing': 'Marketing, Advertising, and Publishing',
    'Book and Periodical Publishing': 'Marketing, Advertising, and Publishing',
    # Creative Arts and Design
    'Artists and Writers': 'Creative Arts and Design',
    'Interior Design': 'Creative Arts and Design',
    'Photography': 'Creative Arts and Design',
    # Miscellaneous and Other Services
    'Janitorial Services': 'Miscellaneous and Other Services',
    'Household Services': 'Miscellaneous and Other Services',
}

# %%
industries['cluster'] = industries['industry_name'].map(cluster_mapping).fillna('Miscellaneous and Other Services')
